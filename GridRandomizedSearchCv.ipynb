# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
dataset = datasets.load_breast_cancer()
print(dataset)

# %%
dataframe = pd.DataFrame(dataset.data, columns = dataset.feature_names)
dataframe['label'] = dataset.target
dataframe.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  label
# 0          0.4601                  0.11890      0
# 1          0.2750                  0.08902      0
# 2          0.3613                  0.08758      0
# 3          0.6638                  0.17300      0
# 4          0.2364                  0.07678      0
#
# [5 rows x 31 columns]

# %%
dataframe.shape
# Out:
# (569, 31)

# %%
dataframe['label'].value_counts()
# Out:
# label
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
X = dataframe.drop(columns='label', axis=1)
y = dataframe['label']
print(X)

# %%
X = np.asarray(X)
y = np.asarray(y)
# Out:
# numpy.ndarray

# %% [markdown]
# ## GridSearchCV

# %%
model = SVC()

# %%
parameters = {
    'kernel':['linear', 'poly', 'rbf', 'sigmoid'],
    'C':[1,5,10,20]
}

# %%
classifier = GridSearchCV(model,parameters, cv=5, verbose=1)

# %%
# fit the data to model
classifier.fit(X,y)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=1)

# %%
classifier.best_params_
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([8.03153563e-01, 2.52442360e-03, 2.52532959e-03, 7.34233856e-03,
#         1.84525547e+00, 2.29983330e-03, 2.37951279e-03, 6.38980865e-03,
#         2.41145563e+00, 2.70586014e-03, 9.01889801e-03, 8.05025101e-03,
#         3.97779508e+00, 2.86035538e-03, 2.76207924e-03, 7.08165169e-03]),
#  'std_fit_time': array([2.93737434e-01, 5.84883887e-04, 4.64902462e-04, 1.21686089e-03,
#         6.92416250e-01, 7.51573802e-04, 8.22058888e-04, 2.78431190e-04,
#         5.14746782e-01, 6.81783320e-04, 8.80887743e-03, 2.69806085e-03,
#         1.22321513e+00, 5.43258994e-04, 3.77283461e-04, 4.04010299e-04]),
#  'mean_score_time': array([0.00092859, 0.0008811 , 0.00240722, 0.00223794, 0.00060215,
#         0.00072532, 0.00164027, 0.00172486, 0.00042748, 0.00120268,
#         0.00242567, 0.00199614, 0.00041099, 0.00019894, 0.00181661,
#         0.00223122]),
#  'std_score_time': array([0.00141023, 0.00092829, 0.00080914, 0.00038501, 0.00049346,
#         0.00064378, 0.00059732, 0.00035188, 0.00052385, 0.00040112,
#         0.00056266, 0.00062708, 0.00050356, 0.00039787, 0.00043559,
#         0.00038981]),
#  'param_C': masked_array(data=[1, 1, 1, 1, 5, 5, 5, 5, 10, 10, 10, 10, 20, 20, 20, 20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['linear', 'poly', 'rbf', 'sigmoid', 'linear', 'poly',
#                     'rbf', 'sigmoid', 'linear', 'poly', 'rbf', 'sigmoid',
#                     'linear', 'poly', 'rbf', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'linear'},
#   {'C': 1, 'kernel': 'poly'},
#   {'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'sigmoid'},
#   {'C': 5, 'kernel': 'linear'},
#   {'C': 5, 'kernel': 'poly'},
#   {'C': 5, 'kernel': 'rbf'},
#   {'C': 5, 'kernel': 'sigmoid'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'poly'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'sigmoid'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'poly'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'sigmoid'}],
#  'split0_test_score': array([0.94736842, 0.84210526, 0.85087719, 0.54385965, 0.94736842,
#         0.88596491, 0.88596491, 0.49122807, 0.93859649, 0.88596491,
#         0.87719298, 0.48245614, 0.92982456, 0.87719298, 0.87719298,
#         0.47368421]),
#  'split1_test_score': array([0.92982456, 0.88596491, 0.89473684, 0.45614035, 0.93859649,
#         0.9122807 , 0.92982456, 0.42105263, 0.93859649, 0.92105263,
#         0.92105263, 0.40350877, 0.95614035, 0.92105263, 0.92105263,
#         0.40350877]),
#  'split2_test_score': array([0.97368421, 0.92982456, 0.92982456, 0.46491228, 0.97368421,
#         0.92105263, 0.93859649, 0.42105263, 0.97368421, 0.90350877,
#         0.9122807 , 0.42105263, 0.95614035, 0.90350877, 0.92105263,
#         0.42105263]),
#  'split3_test_score': array([0.92105263, 0.94736842, 0.94736842, 0.38596491, 0.92982456,
#         0.93859649, 0.94736842, 0.35087719, 0.94736842, 0.93859649,
#         0.95614035, 0.34210526, 0.93859649, 0.93859649, 0.94736842,
#         0.34210526]),
#  'split4_test_score': array([0.95575221, 0.9380531 , 0.9380531 , 0.45132743, 0.96460177,
#         0.95575221, 0.95575221, 0.37168142, 0.96460177, 0.95575221,
#         0.94690265, 0.36283186, 0.96460177, 0.95575221, 0.9380531 ,
#         0.3539823 ]),
#  'mean_test_score': array([0.94553641, 0.90866325, 0.91217202, 0.46044093, 0.95081509,
#         0.92272939, 0.93150132, 0.41117839, 0.95256948, 0.920975  ,
#         0.92271386, 0.40239093, 0.9490607 , 0.91922062, 0.92094395,
#         0.39886664]),
#  'std_test_score': array([0.01868869, 0.03938232, 0.03544367, 0.05025317, 0.01621632,
#         0.02368918, 0.02435811, 0.04857818, 0.01419963, 0.02470123,
#         0.02787898, 0.0489065 , 0.01281637, 0.02730027, 0.02410455,
#         0.0476401 ]),
#  'rank_test_score': array([ 4, 12, 11, 13,  2,  6,  5, 14,  1,  8,  7, 15,  3, 10,  9, 16])}

# %%
# best parameters
best_params = classifier.best_params_

# %%
# loading result to pandas dataframe
result = pd.DataFrame(classifier.cv_results_)
result.head(16)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.803154      0.293737         0.000929        0.001410       1
# 1        0.002524      0.000585         0.000881        0.000928       1
# 2        0.002525      0.000465         0.002407        0.000809       1
# 3        0.007342      0.001217         0.002238        0.000385       1
# 4        1.845255      0.692416         0.000602        0.000493       5
# 5        0.002300      0.000752         0.000725        0.000644       5
# 6        0.002380      0.000822         0.001640        0.000597       5
# 7        0.006390      0.000278         0.001725        0.000352       5
# 8        2.411456      0.514747         0.000427        0.000524      10
# 9        0.002706      0.000682         0.001203        0.000401      10
# 10       0.009019      0.008809         0.002426        0.000563      10
# 11       0.008050      0.002698         0.001996        0.000627      10
# 12       3.977795      1.223215         0.000411        0.000504      20
# 13       0.002860      0.000543         0.000199        0.000398      20
# 14       0.002762      0.000377         0.001817        0.000436      20
# 15       0.007082      0.000404         0.002231        0.000390      20
#
#    param_kernel                          params  split0_test_score  \
# 0        linear    {'C': 1, 'kernel': 'linear'}           0.947368
# 1          poly      {'C': 1, 'kernel': 'poly'}           0.842105
# 2           rbf       {'C': 1, 'kernel': 'rbf'}           0.850877
# 3       sigmoid   {'C': 1, 'kernel': 'sigmoid'}           0.543860
# 4        linear    {'C': 5, 'kernel': 'linear'}           0.947368
# 5          poly      {'C': 5, 'kernel': 'poly'}           0.885965
# 6           rbf       {'C': 5, 'kernel': 'rbf'}           0.885965
# 7       sigmoid   {'C': 5, 'kernel': 'sigmoid'}           0.491228
# 8        linear   {'C': 10, 'kernel': 'linear'}           0.938596
# 9          poly     {'C': 10, 'kernel': 'poly'}           0.885965
# 10          rbf      {'C': 10, 'kernel': 'rbf'}           0.877193
# 11      sigmoid  {'C': 10, 'kernel': 'sigmoid'}           0.482456
# 12       linear   {'C': 20, 'kernel': 'linear'}           0.929825
# 13         poly     {'C': 20, 'kernel': 'poly'}           0.877193
# 14          rbf      {'C': 20, 'kernel': 'rbf'}           0.877193
# 15      sigmoid  {'C': 20, 'kernel': 'sigmoid'}           0.473684
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.929825           0.973684           0.921053
# 1            0.885965           0.929825           0.947368
# 2            0.894737           0.929825           0.947368
# 3            0.456140           0.464912           0.385965
# 4            0.938596           0.973684           0.929825
# 5            0.912281           0.921053           0.938596
# 6            0.929825           0.938596           0.947368
# 7            0.421053           0.421053           0.350877
# 8            0.938596           0.973684           0.947368
# 9            0.921053           0.903509           0.938596
# 10           0.921053           0.912281           0.956140
# 11           0.403509           0.421053           0.342105
# 12           0.956140           0.956140           0.938596
# 13           0.921053           0.903509           0.938596
# 14           0.921053           0.921053           0.947368
# 15           0.403509           0.421053           0.342105
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.955752         0.945536        0.018689                4
# 1            0.938053         0.908663        0.039382               12
# 2            0.938053         0.912172        0.035444               11
# 3            0.451327         0.460441        0.050253               13
# 4            0.964602         0.950815        0.016216                2
# 5            0.955752         0.922729        0.023689                6
# 6            0.955752         0.931501        0.024358                5
# 7            0.371681         0.411178        0.048578               14
# 8            0.964602         0.952569        0.014200                1
# 9            0.955752         0.920975        0.024701                8
# 10           0.946903         0.922714        0.027879                7
# 11           0.362832         0.402391        0.048906               15
# 12           0.964602         0.949061        0.012816                3
# 13           0.955752         0.919221        0.027300               10
# 14           0.938053         0.920944        0.024105                9
# 15           0.353982         0.398867        0.047640               16

# %%
print("higest accuracy is : ", classifier.best_score_)
# Out:
# higest accuracy is :  0.9525694767893185

# %% [markdown]
# ## Randomized SearchCV

# %%
model = SVC()

# %%
classifier = RandomizedSearchCV(model, parameters, cv=5, verbose=1)

# %%
classifier.fit(X, y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [1, 5, 10, 20],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']},
#                    verbose=1)

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([4.30874825e-03, 3.52859497e-03, 3.91564369e-03, 3.21230888e-03,
#         1.89804335e+00, 7.39150047e-03, 5.63874245e-03, 2.46081352e-03,
#         4.18133235e+00, 2.43605013e+00]),
#  'std_fit_time': array([7.50406218e-04, 8.38231239e-04, 1.01882109e-03, 6.81893218e-04,
#         6.87810651e-01, 6.05726251e-04, 6.91472423e-04, 4.90565044e-04,
#         1.37794122e+00, 4.80854329e-01]),
#  'mean_score_time': array([0.00180731, 0.00119352, 0.00266919, 0.00169811, 0.00080099,
#         0.00210657, 0.00158916, 0.0016717 , 0.0007266 , 0.00084853]),
#  'std_score_time': array([0.00051579, 0.00074241, 0.00053772, 0.0004064 , 0.00074901,
#         0.00049063, 0.00048367, 0.00059092, 0.00063231, 0.00072998]),
#  'param_kernel': masked_array(data=['poly', 'poly', 'rbf', 'poly', 'linear', 'sigmoid',
#                     'sigmoid', 'rbf', 'linear', 'linear'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_C': masked_array(data=[20, 10, 1, 1, 5, 5, 20, 10, 20, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'kernel': 'poly', 'C': 20},
#   {'kernel': 'poly', 'C': 10},
#   {'kernel': 'rbf', 'C': 1},
#   {'kernel': 'poly', 'C': 1},
#   {'kernel': 'linear', 'C': 5},
#   {'kernel': 'sigmoid', 'C': 5},
#   {'kernel': 'sigmoid', 'C': 20},
#   {'kernel': 'rbf', 'C': 10},
#   {'kernel': 'linear', 'C': 20},
#   {'kernel': 'linear', 'C': 10}],
#  'split0_test_score': array([0.87719298, 0.88596491, 0.85087719, 0.84210526, 0.94736842,
#         0.49122807, 0.47368421, 0.87719298, 0.92982456, 0.93859649]),
#  'split1_test_score': array([0.92105263, 0.92105263, 0.89473684, 0.88596491, 0.93859649,
#         0.42105263, 0.40350877, 0.92105263, 0.95614035, 0.93859649]),
#  'split2_test_score': array([0.90350877, 0.90350877, 0.92982456, 0.92982456, 0.97368421,
#         0.42105263, 0.42105263, 0.9122807 , 0.95614035, 0.97368421]),
#  'split3_test_score': array([0.93859649, 0.93859649, 0.94736842, 0.94736842, 0.92982456,
#         0.35087719, 0.34210526, 0.95614035, 0.93859649, 0.94736842]),
#  'split4_test_score': array([0.95575221, 0.95575221, 0.9380531 , 0.9380531 , 0.96460177,
#         0.37168142, 0.3539823 , 0.94690265, 0.96460177, 0.96460177]),
#  'mean_test_score': array([0.91922062, 0.920975  , 0.91217202, 0.90866325, 0.95081509,
#         0.41117839, 0.39886664, 0.92271386, 0.9490607 , 0.95256948]),
#  'std_test_score': array([0.02730027, 0.02470123, 0.03544367, 0.03938232, 0.01621632,
#         0.04857818, 0.0476401 , 0.02787898, 0.01281637, 0.01419963]),
#  'rank_test_score': array([ 6,  5,  7,  8,  2,  9, 10,  4,  3,  1])}

# %%
classifier.best_params_
# Out:
# {'kernel': 'linear', 'C': 10}

# %%
classifier.best_score_
# Out:
# 0.9525694767893185
