# %%
import numpy as np
from sklearn.cluster import MeanShift
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
X, y = make_blobs(n_samples=200, centers=2, random_state=0)
X.shape
# Out:
# (200, 2)

# %%
# Apply Mean Shift
ms = MeanShift()

# %%
ms.fit(X)
# Out:
# MeanShift()

# %%
labels = ms.labels_

# %%
clusters_centers = ms.cluster_centers_

# %%
plt.scatter(X[:,0],X[:,1], c= y)
plt.scatter(clusters_centers[:,0], clusters_centers[:,1], marker='x')
plt.show()

# %%
# Apply Mean Shift on another dataset
from sklearn.cluster import estimate_bandwidth

# %%
centers = [[1,1],[-1,-1],[1,-1]]
X, _ = make_blobs(n_samples=10000, centers=centers, cluster_std=0.6)

# %%
bandwidth = estimate_bandwidth(X, quantile=0.2,n_samples=500)
print(bandwidth)
# Out:
# 1.0598837370215815

# %%
ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X)
# Out:
# MeanShift(bandwidth=1.0598837370215815, bin_seeding=True)

# %%
labels = ms.labels_
clusters_centers = ms.cluster_centers_

# %%
plt.scatter(X[:,0],X[:,1], c=labels)
plt.scatter(clusters_centers[:,0], clusters_centers[:,1], marker='x')
plt.show()
